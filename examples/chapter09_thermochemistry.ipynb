# %% [markdown]
# ### Chapter 9: Thermochemistry

# %%
from chemchem.core import *
from chemchem.compound import Compound
from chemchem.reaction import Reaction

# %%
Ag = Compound('Ag')

# %%
Ag.setName('Silver')

# %%
Ag.setAmount(mass=Q(1.2, 'kilograms'))

# %%
Ag.setSpecificHeat(Q(0.235, Unit.SPECIFIC_HEAT))
# Out:
# 0.235 <Unit('joule / kelvin / kilogram')>

# %%
Ag.__dict__
# Out:
# {'occurences': {'Ag': 1},
#  'elements': [<chemlib.chemistry.Element>],
#  'formula': 'Ag₁',
#  'coefficient': 1,
#  'name': 'Silver',
#  'mass': 1.2 <Unit('kilogram')>,
#  'mass_t': <chemchem.core.Symbol>,
#  'moles': 11.12470797641562 <Unit('mole')>,
#  'specific_heat': 0.235 <Unit('joule / kelvin / kilogram')>,
#  'temperature': 0    None
#  Name: temperature, dtype: object}

# %%
Ag.heat(change_in_temperature=Q(21, Unit.TEMPERATURE))
# Out:
# 5.922 <Unit('joule')>

# %%
Ag.heat_capacity
# Out:
# 0.282 <Unit('joule / kelvin')>

# %% [markdown]
# ![image.png](attachment:96e29b80-1d2f-45d7-ad0c-2fa7e14fabce.png)

# %%
H2O = Compound('H2O')

# %%
H2O.setAmount(mass=Q(7.60, 'kilogram'))

# %%
initial_temperature = Q(32, 'celsius')

# %%
heat_gain = Q(130, 'kJ')

# %% [markdown]
# ### Bomb Calorimeter

# %% [markdown]
# ![image.png](attachment:63979f13-8d9d-4ec7-984a-bbcc10d1deaf.png)
