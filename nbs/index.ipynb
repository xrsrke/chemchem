# %%
#| hide
from chemlib import Compound, Element

from chemchem.core import *

# %% [markdown]
# # chemchem
#
# > A chemistry package!

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Install

# %% [markdown]
# ```sh
# pip install chemchem
# ```

# %% [markdown]
# ### Thermochemistry

# %% [markdown]
# ![image.png](attachment:fc7d218a-d42f-4294-b17c-768c6e3f5836.png)

# %%
Al = Compound('Al')

# %%
Al.get_amounts(grams=32.5)
# Out:
# {'grams': 32.5, 'molecules': 7.251130383218443e+23, 'moles': 1.204506708175821}

# %%
#Al.properties

# %%
H2O = Compound('H2O')
